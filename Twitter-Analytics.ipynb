# %% [markdown]
# # Twitter Analytics
#
#
# ### Is Twitter a LEGITIMATE platform for Marketing Campaigns?
#
# ### We analyzed the Top 2 Valuable Sports Brands in 2019 using Twitter to understand the reach of Social Media

# %% [markdown]
# ![IMG_1113.jpg](attachment:IMG_1113.jpg)

# %%
import pandas as pd
import matplotlib
import json
from twython import Twython

# %%
# Load credentials from json file
with open("twitter_credentials.json", "r") as file:
   creds = json.load(file)

# Instantiate an object
python_tweets = Twython(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])

# Create our query
query = {'q': 'nike',
       'result_type': 'popular',
       'count': 15,
        'lang': 'en',
       }
# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': [], "followers_count":[],
        "user_favourites_count":[], "user_created_at": [] ,"retweet_count": [], "statuses_count":[], "hashtags":[] }
for status in python_tweets.search(**query)['statuses']:
   dict_['user'].append(status['user']['screen_name'])
   dict_['date'].append(status['created_at'])
   dict_['text'].append(status['text'])
   dict_['favorite_count'].append(status['favorite_count'])
   dict_['followers_count'].append(status['user']['followers_count'])
   dict_['user_favourites_count'].append(status['user']['favourites_count'])
   dict_['statuses_count'].append(status['user']['statuses_count'])
   dict_['user_created_at'].append(status['user']['created_at'])
   dict_['hashtags'].append(status['entities']['hashtags']) 
   dict_['retweet_count'].append(status['retweet_count'])

# Structure data in a pandas DataFrame for easier manipulation
df = pd.DataFrame(dict_)
df.sort_values(by='followers_count', ascending=True)
df.head(100)
# Out:
#                user                            date  \
# 0       FCBarcelona  Fri Mar 01 00:25:05 +0000 2019
# 1   RealBillRussell  Thu Feb 28 12:02:09 +0000 2019
# 2          UN_Women  Thu Feb 28 14:35:08 +0000 2019
# 3        lplenglish  Thu Feb 28 12:12:45 +0000 2019
# 4           brkicks  Wed Feb 27 21:40:44 +0000 2019
# 5             Sporf  Thu Feb 28 17:25:33 +0000 2019
# 6            clegfx  Thu Feb 28 17:11:36 +0000 2019
# 7   archanakalpathi  Thu Feb 28 09:16:20 +0000 2019
# 8            J23app  Wed Feb 27 22:08:35 +0000 2019
# 9     SoleCollector  Thu Feb 28 05:36:48 +0000 2019
# 10         ThornsFC  Wed Feb 27 23:49:33 +0000 2019
# 11       KicksDeals  Thu Feb 28 21:15:35 +0000 2019
# 12        MailSport  Thu Feb 28 08:30:02 +0000 2019
# 13         GoalNews  Thu Feb 28 09:30:00 +0000 2019
# 14  TheSupremeSaint  Wed Feb 27 22:15:50 +0000 2019
#
#                                                  text  favorite_count  \
# 0   🔵🔴 It's much easier to get a #Messi shirt by g...           31437
# 1   On the final day of #BlackHistoryMonth  I want...           17394
# 2   "It’s only crazy until you do it."\n\nThis @Ni...            1422
# 3   LPL x Nike\n\nStarting from the 2019 Mid-Seaso...             968
# 4   .@Giannis_An34 reacting to a photo of his sign...            4031
# 5   💰 Biggest kit deals in world Football (per yea...             980
# 6   Heres another pic of my new AF1 Wraiths! Took ...            1386
# 7   Just loved this one. If you think crazy works ...            1874
# 8   Supreme x Nike Air Max Tailwind IV "White/Red"...            1086
# 9   “Buzz Lightyear” Nike LeBron 16s for @kingjame...             827
# 10  🔴Coming⚪️Soon⚫️\n\nOur new, fully custom @Nike...             801
# 11  ⚾️🔥 Get ready for the season! NEW MLB x Nike A...             251
# 12  Man City agree staggering 10-year, £650m deal ...             279
# 13  Goodbye Nike 👋\n\nManchester City have landed ...             450
# 14  Supreme x Nike Air Max Tailwind IV "White/Red"...             291
#
#     followers_count  user_favourites_count                 user_created_at  \
# 0          29179446                   1994  Tue Dec 15 09:53:50 +0000 2009
# 1            101075                    109  Mon Sep 25 16:54:07 +0000 2017
# 2           1566154                   4901  Mon Nov 03 19:28:09 +0000 2008
# 3             15596                     80  Fri Dec 22 06:25:25 +0000 2017
# 4            274546                    383  Wed Dec 16 20:17:02 +0000 2015
# 5           1238214                   1715  Tue Mar 27 10:00:15 +0000 2012
# 6             10879                   2383  Wed Jun 17 01:24:24 +0000 2009
# 7            438091                   1779  Thu Sep 02 08:00:08 +0000 2010
# 8            271556                   9051  Sun Feb 12 02:00:39 +0000 2012
# 9            539324                   2058  Fri Jan 23 05:11:25 +0000 2009
# 10            85082                  14259  Wed Nov 21 17:38:26 +0000 2012
# 11           379048                  42864  Wed Aug 24 16:30:26 +0000 2011
# 12           353280                    498  Fri Feb 05 10:19:11 +0000 2010
# 13           393938                     91  Sun Sep 13 07:58:38 +0000 2009
# 14           113969                    351  Thu Apr 03 23:07:20 +0000 2014
#
#     retweet_count  statuses_count  \
# 0           11483          100775
# 1            3788             421
# 2             632           53537
# 3             258            1520
# 4             566           13338
# 5             186            6001
# 6             217            4213
# 7             182            5222
# 8             209           56145
# 9              99           88173
# 10             97           22986
# 11             52          157582
# 12            122          235800
# 13             79          208760
# 14             67           17946
#
#                                              hashtags
# 0            [{'text': 'Messi', 'indices': [29, 35]}]
# 1   [{'text': 'BlackHistoryMonth', 'indices': [20,...
# 2     [{'text': 'WomenInSport', 'indices': [59, 72]}]
# 3                                                  []
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7   [{'text': 'Nike', 'indices': [58, 63]}, {'text...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []

# %%
# Create our query
query = {'q': 'adidas',
       'result_type': 'popular',
       'count': 15,
        'lang': 'en',
       }

# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': [], "followers_count":[],
        "user_favourites_count":[], "user_created_at": [] ,"retweet_count": [], "statuses_count":[], "hashtags":[] }
for status in python_tweets.search(**query)['statuses']:
   dict_['user'].append(status['user']['screen_name'])
   dict_['date'].append(status['created_at'])
   dict_['text'].append(status['text'])
   dict_['favorite_count'].append(status['favorite_count'])
   dict_['followers_count'].append(status['user']['followers_count'])
   dict_['user_favourites_count'].append(status['user']['favourites_count'])
   dict_['statuses_count'].append(status['user']['statuses_count'])
   dict_['user_created_at'].append(status['user']['created_at'])
   dict_['hashtags'].append(status['entities']['hashtags']) 
   dict_['retweet_count'].append(status['retweet_count'])

# Structure data in a pandas DataFrame for easier manipulation
df = pd.DataFrame(dict_)
df.sort_values(by='followers_count', ascending=True)
df.head(100)
# Out:
#                user                            date  \
# 0     KendallJenner  Thu Feb 28 19:10:40 +0000 2019
# 1            ImRo45  Thu Feb 28 07:33:22 +0000 2019
# 2         FOXSoccer  Thu Feb 28 21:52:04 +0000 2019
# 3             Sporf  Thu Feb 28 17:25:33 +0000 2019
# 4          NBAKicks  Fri Mar 01 00:02:17 +0000 2019
# 5          slmandel  Thu Feb 28 19:20:46 +0000 2019
# 6   samuelluckhurst  Thu Feb 28 14:10:26 +0000 2019
# 7         HYPEBEAST  Thu Feb 28 02:49:48 +0000 2019
# 8      highsnobiety  Thu Feb 28 16:57:54 +0000 2019
# 9     SoleCollector  Fri Mar 01 04:00:12 +0000 2019
# 10     VibeMagazine  Thu Feb 28 00:30:00 +0000 2019
# 11              XXL  Thu Feb 28 16:51:28 +0000 2019
# 12    SoleCollector  Wed Feb 27 22:17:31 +0000 2019
# 13          brkicks  Wed Feb 27 21:04:03 +0000 2019
# 14         droid254  Thu Feb 28 08:22:33 +0000 2019
#
#                                                  text  favorite_count  \
# 0   don’t mind me #adidasSLEEK @adidasoriginals #c...           16539
# 1   Saving the ocean one shoe at a time 👏 So proud...           10738
# 2   She's a beauty 😍\n\nThe official match ball fo...            2020
# 3   💰 Biggest kit deals in world Football (per yea...             981
# 4   🏀 @JHarden13 laces up his adidas Harden Vol. 3...            1649
# 5   Poor, poor Kansas basketball. Just a helpless ...             374
# 6   Given the 'achievements' (🙄) highlighted in #m...             463
# 7   Peep the upcoming @adidas #YEEZY sneaker. \nht...             716
# 8   Apple, adidas &amp; Netflix logos redesigned t...             251
# 9   .@jharden13 went off for 58 points in the Adid...             343
# 10  Kanye West is reportedly gunning to become new...              84
# 11  Kanye West says he's been fighting to be the c...             304
# 12  Kristen Noel Crawley with an in-hand look at t...             411
# 13  An on-feet look at the Adidas Yeezy 700 V2 “Ge...             519
# 14  If I was to do a list of the most counterfeite...             122
#
#     followers_count  user_favourites_count                 user_created_at  \
# 0          27393109                   4260  Sat Jun 19 00:03:11 +0000 2010
# 1          13295389                    280  Mon Mar 08 08:56:53 +0000 2010
# 2           1273059                   1243  Thu Mar 04 02:57:00 +0000 2010
# 3           1238212                   1715  Tue Mar 27 10:00:15 +0000 2012
# 4             20061                      3  Mon Oct 15 16:58:17 +0000 2018
# 5            190502                    502  Tue Mar 31 18:48:05 +0000 2009
# 6             86998                    697  Tue Aug 24 08:44:35 +0000 2010
# 7            622601                   2244  Sun Dec 21 15:54:27 +0000 2008
# 8            327044                    893  Wed Dec 19 01:55:17 +0000 2007
# 9            539325                   2058  Fri Jan 23 05:11:25 +0000 2009
# 10           875723                   3250  Wed May 07 20:13:54 +0000 2008
# 11          2012104                   3034  Fri May 02 18:29:28 +0000 2008
# 12           539325                   2058  Fri Jan 23 05:11:25 +0000 2009
# 13           274546                    383  Wed Dec 16 20:17:02 +0000 2015
# 14            50636                   1492  Fri Jun 22 16:38:47 +0000 2012
#
#     retweet_count  statuses_count  \
# 0            1131            9373
# 1             824            2070
# 2             299          115598
# 3             186            6001
# 4             171             714
# 5              79           48919
# 6              66           91440
# 7             106          119052
# 8              55            9219
# 9              39           88173
# 10             36          208589
# 11             55          211808
# 12             56           88173
# 13             70           13338
# 14             64          136447
#
#                                              hashtags
# 0   [{'text': 'adidasSLEEK', 'indices': [14, 26]},...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4         [{'text': 'NBAKicks', 'indices': [56, 65]}]
# 5                                                  []
# 6             [{'text': 'mufc', 'indices': [44, 49]}]
# 7            [{'text': 'YEEZY', 'indices': [26, 32]}]
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []

# %%
# Create our query
query = {'q': '#ad',
       'result_type': 'mixed',
       'count': 100,
        'lang': 'en',
       }
# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': [], "followers_count":[],
        "user_favourites_count":[], "user_created_at": [] ,"retweet_count": [], "statuses_count":[], "hashtags":[] }
for status in python_tweets.search(**query)['statuses']:
    if (status['entities']['hashtags'])  == 'ad':
       dict_['user'].append(status['user']['screen_name'])
       dict_['favorite_count'].append(status['favorite_count'])
       dict_['followers_count'].append(status['user']['followers_count'])
       dict_['hashtags'].append(status['entities']['hashtags']) 
  

# Structure data in a pandas DataFrame for easier manipulation
df = pd.DataFrame(dict_)
df.sort_values(by='followers_count', ascending=True)
df.head(100)
# Out:
# Empty DataFrame
# Columns: [user, date, text, favorite_count, followers_count, user_favourites_count, user_created_at, retweet_count, statuses_count, hashtags]
# Index: []
